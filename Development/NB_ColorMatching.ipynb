# %% [markdown]
# # Color Matching

# %% [markdown]
# ## Import requirements

# %%
import numpy as np
import matplotlib.pyplot as plt

#fuzzy logic
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import colorsys
